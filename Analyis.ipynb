# %%
# from utils import load_from_pickle

from utils import load_from_pickle
from matplotlib import pyplot as plt
import matplotlib as mpl

# Avoid Type 3 fonts in PDF/PS/SVG
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['svg.fonttype'] = 'none'

# Use built-in mathtext Computer Modern
mpl.rcParams['text.usetex'] = False        # don't call external LaTeX
mpl.rcParams['mathtext.fontset'] = 'cm'    # Computer Modern for math
mpl.rcParams['font.family'] = 'DejaVu Serif'  # fallback serif font

# %% [markdown]
# # Explore

# %%
data_dict = {
    "Maximum Coverage": {
        "QuickPrune": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.9953, "C": 0.9953},
            "Wiki": {"P_r": 0.9998, "P_g": 0.9422, "C": 0.9420},
            "Deezer": {"P_r": 0.9606, "P_g": 0.9797, "C": 0.9411},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.9925, "C": 0.9925},
            "Twitter": {"P_r": 0.9929, "P_g": 0.9911, "C": 0.9841},
            "DBLP": {"P_r": 0.9951, "P_g": 0.9957, "C": 0.9908},
            "YouTube": {"P_r": 1.0000, "P_g": 0.9995, "C": 0.9995},
            "Skitter": {"P_r": 0.9985, "P_g": 0.9997, "C": 0.9982},
        },
        "SS": {
            "Facebook": {"P_r": 0.9884, "P_g": 0.9027, "C": 0.8922},
            "Wiki": {"P_r": 0.9559, "P_g": 0.9346, "C": 0.8934},
            "Deezer": {"P_r": 0.9870, "P_g": 0.9855, "C": 0.9727},
            "Slashdot": {"P_r": 0.9824, "P_g": 0.9889, "C": 0.9715},
            "Twitter": {"P_r": 0.9306, "P_g": 0.9893, "C": 0.9206},
            "DBLP": {"P_r": 0.9945, "P_g": 0.9963, "C": 0.9908},
            "YouTube": {"P_r": 0.9999, "P_g": 0.9987, "C": 0.9986},
            "Skitter": {"P_r": 0.9857, "P_g": 0.9991, "C": 0.9848},
        },
        "GCOMB-P": {
            "Facebook": {"P_r": 0.9270, "P_g": 0.0700, "C": 0.0649},
            "Wiki": {"P_r": 0.9900, "P_g": 0.0300, "C": 0.0297},
            "Deezer": {"P_r": 0.9940, "P_g": 0.1300, "C": 0.1292},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.0200, "C": 0.0200},
            "Twitter": {"P_r": 0.9970, "P_g": 0.1700, "C": 0.1695},
            "DBLP": {"P_r": 0.9990, "P_g": 0.0300, "C": 0.0300},
            "YouTube": {"P_r": 0.9980, "P_g": 0.0700, "C": 0.0699},
            "Skitter": {"P_r": 0.9990, "P_g": 0.1000, "C": 0.0999},
        },
        "COMBHelper": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.3840, "C": 0.3840},
            "Wiki": {"P_r": 1.0000, "P_g": 0.4528, "C": 0.4528},
            "Deezer": {"P_r": 1.0000, "P_g": 0.7278, "C": 0.7278},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.9844, "C": 0.9844},
            "Twitter": {"P_r": 1.0000, "P_g": 0.5654, "C": 0.5654},
            "DBLP": {"P_r": 1.0000, "P_g": 0.1818, "C": 0.1818},
            "YouTube": {"P_r": 1.0000, "P_g": 0.9572, "C": 0.9572},
            "Skitter": {"P_r": None, "P_g": None, "C": None},
        },
        "LeNSE": {
            "Facebook": {"P_r": 0.9660, "P_g": 0.0700, "C": 0.0676},
            "Wiki": {"P_r": 1.0940, "P_g": 0.3400, "C": 0.3720},
            "Deezer": {"P_r": 0.9790, "P_g": 0.7500, "C": 0.7343},
            "Slashdot": {"P_r": 0.9790, "P_g": 0.6900, "C": 0.6755},
            "Twitter": {"P_r": 0.9890, "P_g": 0.3300, "C": 0.3264},
            "DBLP": {"P_r": 0.9900, "P_g": 0.9000, "C": 0.8910},
            "YouTube": {"P_r": 0.9820, "P_g": 0.7900, "C": 0.7758},
            "Skitter": {"P_r": 0.9760, "P_g": 0.7000, "C": 0.6832},
        },
        "GNN": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.7697, "C": 0.7697},
            "Wiki": {"P_r": 1.0000, "P_g": 0.9199, "C": 0.9199},
            "Deezer": {"P_r": 1.0000, "P_g": 0.9151, "C": 0.9151},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.9810, "C": 0.9810},
            "Twitter": {"P_r": 0.9987, "P_g": 0.9793, "C": 0.9780},
            "DBLP": {"P_r": 1.0000, "P_g": 0.8705, "C": 0.8705},
            "YouTube": {"P_r": 0.9947, "P_g": 0.9967, "C": 0.9914},
            "Skitter": {"P_r": 0.9993, "P_g": 0.9891, "C": 0.9884},
        },
    },

    "Maximum Cut": {
        "QuickPrune": {
            "Facebook": {"P_r": 0.9886, "P_g": 0.7935, "C": 0.7845},
            "Wiki": {"P_r": 0.9985, "P_g": 0.9037, "C": 0.9023},
            "Deezer": {"P_r": 0.9996, "P_g": 0.9730, "C": 0.9726},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.9904, "C": 0.9904},
            "Twitter": {"P_r": 1.0000, "P_g": 0.9900, "C": 0.9900},
            "DBLP": {"P_r": 1.0000, "P_g": 0.9954, "C": 0.9954},
            "YouTube": {"P_r": 1.0000, "P_g": 0.9994, "C": 0.9994},
            "Skitter": {"P_r": 1.0000, "P_g": 0.9995, "C": 0.9995},
        },
        "SS": {
            "Facebook": {"P_r": 0.9928, "P_g": 0.9027, "C": 0.8962},
            "Wiki": {"P_r": 0.9981, "P_g": 0.9346, "C": 0.9328},
            "Deezer": {"P_r": 0.9999, "P_g": 0.9855, "C": 0.9854},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.9889, "C": 0.9889},
            "Twitter": {"P_r": 1.0000, "P_g": 0.9893, "C": 0.9893},
            "DBLP": {"P_r": 1.0000, "P_g": 0.9963, "C": 0.9963},
            "YouTube": {"P_r": 1.0000, "P_g": 0.9987, "C": 0.9987},
            "Skitter": {"P_r": 1.0000, "P_g": 0.9991, "C": 0.9991},
        },
        "GCOMB-P": {
            "Facebook": {"P_r": 0.8130, "P_g": 0.9500, "C": 0.7723},
            "Wiki": {"P_r": 0.9200, "P_g": 0.9600, "C": 0.8832},
            "Deezer": {"P_r": 0.8500, "P_g": 0.9900, "C": 0.8415},
            "Slashdot": {"P_r": 0.6320, "P_g": 0.9900, "C": 0.6257},
            "Twitter": {"P_r": 0.6280, "P_g": 0.9900, "C": 0.6217},
            "DBLP": {"P_r": 0.6460, "P_g": 0.9900, "C": 0.6395},
            "YouTube": {"P_r": 0.5360, "P_g": 0.9900, "C": 0.5306},
            "Skitter": {"P_r": 0.4270, "P_g": 0.9900, "C": 0.4227},
        },
        "COMBHelper": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.1538, "C": 0.1538},
            "Wiki": {"P_r": 1.0000, "P_g": 0.7011, "C": 0.7011},
            "Deezer": {"P_r": 1.0000, "P_g": 0.3754, "C": 0.3754},
            "Slashdot": {"P_r": 0.7935, "P_g": 0.9929, "C": 0.7879},
            "Twitter": {"P_r": 1.0000, "P_g": 0.5542, "C": 0.5542},
            "DBLP": {"P_r": 1.0000, "P_g": 0.1825, "C": 0.1825},
            "YouTube": {"P_r": 0.9990, "P_g": 0.9705, "C": 0.9695},
            "Skitter": {"P_r": None, "P_g": None, "C": None},
        },
        "LeNSE": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.0700, "C": 0.0700},
            "Wiki": {"P_r": 0.9810, "P_g": 0.3900, "C": 0.3826},
            "Deezer": {"P_r": 0.9750, "P_g": 0.7400, "C": 0.7215},
            "Slashdot": {"P_r": 0.9900, "P_g": 0.6200, "C": 0.6138},
            "Twitter": {"P_r": 0.9870, "P_g": 0.4800, "C": 0.4738},
            "DBLP": {"P_r": 0.9930, "P_g": 0.9200, "C": 0.9136},
            "YouTube": {"P_r": 0.9870, "P_g": 0.7900, "C": 0.7797},
            "Skitter": {"P_r": 0.9740, "P_g": 0.7100, "C": 0.6915},
        },
        "GNN": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.6774, "C": 0.6774},
            "Wiki": {"P_r": 1.0000, "P_g": 0.9004, "C": 0.9004},
            "Deezer": {"P_r": 1.0000, "P_g": 0.9188, "C": 0.9188},
            "Slashdot": {"P_r": 1.0000, "P_g": 0.9797, "C": 0.9797},
            "Twitter": {"P_r": 1.0000, "P_g": 0.9740, "C": 0.9740},
            "DBLP": {"P_r": 1.0000, "P_g": 0.8623, "C": 0.8623},
            "YouTube": {"P_r": 0.9936, "P_g": 0.9968, "C": 0.9904},
            "Skitter": {"P_r": 1.0000, "P_g": 0.9884, "C": 0.9884},
        },
    },

    "Influence Maximization": {
        "QuickPrune": {
            "Facebook": {"P_r": 0.9919, "P_g": 0.7450, "C": 0.7390},
            "Wiki": {"P_r": 1.0269, "P_g": 0.8831, "C": 0.9069},
            "Deezer": {"P_r": 0.9384, "P_g": 0.9698, "C": 0.9101},
            "Slashdot": {"P_r": 0.9984, "P_g": 0.9881, "C": 0.9865},
            "Twitter": {"P_r": 1.0045, "P_g": 0.9965, "C": 1.0010},
            "DBLP": {"P_r": 0.8603, "P_g": 0.9946, "C": 0.8557},
            "YouTube": {"P_r": 0.9677, "P_g": 0.9994, "C": 0.9671},
            "Skitter": {"P_r": 0.9813, "P_g": 0.9999, "C": 0.9812},
        },
        "SS": {
            "Facebook": {"P_r": 0.9208, "P_g": 0.9027, "C": 0.8312},
            "Wiki": {"P_r": 0.9863, "P_g": 0.9346, "C": 0.9218},
            "Deezer": {"P_r": 1.0262, "P_g": 0.9855, "C": 1.0113},
            "Slashdot": {"P_r": 0.9959, "P_g": 0.9889, "C": 0.9848},
            "Twitter": {"P_r": 0.9575, "P_g": 0.9893, "C": 0.9473},
            "DBLP": {"P_r": 1.0495, "P_g": 0.9963, "C": 1.0456},
            "YouTube": {"P_r": 0.9846, "P_g": 0.9987, "C": 0.9833},
            "Skitter": {"P_r": 1.0032, "P_g": 0.9991, "C": 1.0023},
        },
        "GCOMB-P": {
            "Facebook": {"P_r": 0.9510, "P_g": 0.7300, "C": 0.6942},
            "Wiki": {"P_r": 0.9690, "P_g": 0.9000, "C": 0.8721},
            "Deezer": {"P_r": 0.8050, "P_g": 0.5500, "C": 0.4428},
            "Slashdot": {"P_r": 0.9660, "P_g": 0.9800, "C": 0.9467},
            "Twitter": {"P_r": 0.9200, "P_g": 0.9800, "C": 0.9016},
            "DBLP": {"P_r": 0.8630, "P_g": 0.9900, "C": 0.8544},
            "YouTube": {"P_r": 0.9330, "P_g": 0.9900, "C": 0.9237},
            "Skitter": {"P_r": 0.8830, "P_g": 0.9900, "C": 0.8742},
        },
        "COMBHelper": {
            "Facebook": {"P_r": 1.0039, "P_g": 0.3248, "C": 0.3261},
            "Wiki": {"P_r": 0.9969, "P_g": 0.6066, "C": 0.6047},
            "Deezer": {"P_r": 0.9837, "P_g": 0.1093, "C": 0.1075},
            "Slashdot": {"P_r": 1.0076, "P_g": 0.9875, "C": 0.9950},
            "Twitter": {"P_r": 0.9972, "P_g": 0.4947, "C": 0.4933},
            "DBLP": {"P_r": 0.9873, "P_g": 0.0194, "C": 0.0192},
            "YouTube": {"P_r": 0.9992, "P_g": 0.9705, "C": 0.9697},
            "Skitter": {"P_r": None, "P_g": None, "C": None},
        },
        "LeNSE": {
            "Facebook": {"P_r": 0.9790, "P_g": 0.0900, "C": 0.0881},
            "Wiki": {"P_r": 0.9600, "P_g": 0.5100, "C": 0.4896},
            "Deezer": {"P_r": 0.9720, "P_g": 0.7600, "C": 0.7387},
            "Slashdot": {"P_r": 0.9660, "P_g": 0.7700, "C": 0.7438},
            "Twitter": {"P_r": 0.9660, "P_g": 0.4000, "C": 0.3864},
            "DBLP": {"P_r": 0.9690, "P_g": 0.8900, "C": 0.8624},
            "YouTube": {"P_r": 0.9710, "P_g": 0.7500, "C": 0.7282},
            "Skitter": {"P_r": 0.9830, "P_g": 0.7800, "C": 0.7667},
        },
        "GNN": {
            "Facebook": {"P_r": 0.9938, "P_g": 0.4917, "C": 0.4887},
            "Wiki": {"P_r": 1.0011, "P_g": 0.8964, "C": 0.8974},
            "Deezer": {"P_r": 0.9984, "P_g": 0.8478, "C": 0.8464},
            "Slashdot": {"P_r": 0.9993, "P_g": 0.9797, "C": 0.9790},
            "Twitter": {"P_r": 0.9842, "P_g": 0.9758, "C": 0.9604},
            "DBLP": {"P_r": 0.7558, "P_g": 0.3325, "C": 0.2513},
            "YouTube": {"P_r": 1.0018, "P_g": 0.9966, "C": 0.9984},
            "Skitter": {"P_r": 1.0023, "P_g": 0.9889, "C": 0.9912},
        },
    },

    "Maximum Coverage Weighted": {
        "QuickPrune": {
            "Facebook": {"P_r": 0.9725, "P_g": 0.9871, "C": 0.9600},
            "Wiki": {"P_r": 0.9400, "P_g": 0.9851, "C": 0.9260},
            "Deezer": {"P_r": 0.8750, "P_g": 0.9983, "C": 0.8735},
            "Slashdot": {"P_r": 0.8950, "P_g": 0.9988, "C": 0.8939},
            "Twitter": {"P_r": 0.8700, "P_g": 0.9987, "C": 0.8689},
            "DBLP": {"P_r": 0.8450, "P_g": 0.9997, "C": 0.8447},
            "YouTube": {"P_r": 0.9150, "P_g": 0.9999, "C": 0.9149},
            "Skitter": {"P_r": 0.9050, "P_g": 0.9999, "C": 0.9049}
        },
        "TOP-k": {
            "Facebook": {"P_r": 0.5505, "P_g": 0.9871, "C": 0.5434},
            "Wiki": {"P_r": 0.7550, "P_g": 0.9851, "C": 0.7438},
            "Deezer": {"P_r": 0.9150, "P_g": 0.9983, "C": 0.9134},
            "Slashdot": {"P_r": 0.5700, "P_g": 0.9988, "C": 0.5693},
            "Twitter": {"P_r": 0.5950, "P_g": 0.9987, "C": 0.5942},
            "DBLP": {"P_r": 0.7150, "P_g": 0.9997, "C": 0.7148},
            "YouTube": {"P_r": 0.5200, "P_g": 0.9999, "C": 0.5199},
            "Skitter": {"P_r": 0.8150, "P_g": 0.9999, "C": 0.8149}
        }
    },

    "Maximum Cut Weighted": {
        "QuickPrune": {
            "Facebook": {"P_r": 0.9899, "P_g": 0.9666, "C": 0.9568},
            "Wiki": {"P_r": 0.9600, "P_g": 0.9928, "C": 0.9531},
            "Deezer": {"P_r": 0.9600, "P_g": 0.9985, "C": 0.9586},
            "Slashdot": {"P_r": 0.9700, "P_g": 0.9991, "C": 0.9691},
            "Twitter": {"P_r": 0.9500, "P_g": 0.9996, "C": 0.9496},
            "DBLP": {"P_r": 0.9500, "P_g": 0.9999, "C": 0.9499},
            "YouTube": {"P_r": 0.9700, "P_g": 0.9999, "C": 0.9699},
            "Skitter": {"P_r": 0.9700, "P_g": 0.9999, "C": 0.9699}
        },
        "TOP-k": {
            "Facebook": {"P_r": 1.0000, "P_g": 0.9666, "C": 0.9666},
            "Wiki": {"P_r": 0.5100, "P_g": 0.9928, "C": 0.5063},
            "Deezer": {"P_r": 0.8000, "P_g": 0.9985, "C": 0.7988},
            "Slashdot": {"P_r": 0.6700, "P_g": 0.9991, "C": 0.6694},
            "Twitter": {"P_r": 0.2900, "P_g": 0.9996, "C": 0.2899},
            "DBLP": {"P_r": 0.4300, "P_g": 0.9999, "C": 0.4300},
            "YouTube": {"P_r": 0.7300, "P_g": 0.9999, "C": 0.7299},
            "Skitter": {"P_r": 1.0000, "P_g": 0.9999, "C": 0.9999}
        }
    },

    "Influence Maximization Weighted": {
        "QuickPrune": {
            "Facebook": {"P_r": 0.9934, "P_g": 0.9148, "C": 0.9088},
            "Wiki": {"P_r": 0.9660, "P_g": 0.8774, "C": 0.8476},
            "Deezer": {"P_r": 1.0000, "P_g": 0.9820, "C": 0.9820},
            "Slashdot": {"P_r": 0.9132, "P_g": 0.9868, "C": 0.9011},
            "Twitter": {"P_r": 0.9121, "P_g": 0.9986, "C": 0.9108},
            "DBLP": {"P_r": 1.0000, "P_g": 0.9958, "C": 0.9958},
            "YouTube": {"P_r": 0.9171, "P_g": 0.9994, "C": 0.9165},
            "Skitter": {"P_r": 0.8291, "P_g": 0.9999, "C": 0.8290}
        },
        "TOP-k": {
            "Facebook": {"P_r": 0.9934, "P_g": 0.9148, "C": 0.9088},
            "Wiki": {"P_r": 1.0000, "P_g": 0.8774, "C": 0.8774},
            "Deezer": {"P_r": 1.0000, "P_g": 0.9820, "C": 0.9820},
            "Slashdot": {"P_r": 1.0120, "P_g": 0.9868, "C": 0.9986},
            "Twitter": {"P_r": 0.9689, "P_g": 0.9986, "C": 0.9675},
            "DBLP": {"P_r": 1.0000, "P_g": 0.9958, "C": 0.9958},
            "YouTube": {"P_r": 0.9502, "P_g": 0.9994, "C": 0.9496},
            "Skitter": {"P_r": 0.9391, "P_g": 0.9999, "C": 0.9390}
        }
    }
}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

for problem in [
                'Maximum Coverage',
                'Maximum Cut',
                'Influence Maximization',
                'Maximum Coverage Weighted',
                'Maximum Cut Weighted',
                'Influence Maximization Weighted'
                ]:
    datasets = ['Facebook', 'DBLP', 'Deezer', 'Slashdot', 'Wiki', 'Twitter', 'YouTube','Skitter']

    try:
        data_dict[problem]['LLM2Prune'] = {}
    except:
        data_dict[problem] = {}
        data_dict[problem]['LLM2Prune'] = {}


    for dataset in datasets:
        try:
            results = load_from_pickle(f'{problem}/{dataset}/results/{dataset}.pkl')

            ratio = float(results['Ratio'].iloc[0])
            size = float(results['Size Reduction'].iloc[0])
            combined = ratio * size

            data_dict[problem]['LLM2Prune'][dataset] = {
                "P_r": round(ratio, 4),
                "P_g": round(size, 4),
                "C": round(combined, 4)
            }
        except Exception as e:
            pass

def plot_algo_comparison(data_dict, problems, algos_to_plot, figsize=(12, 6)):
    for problem in problems:
        rows = []
        for algo, datasets in data_dict[problem].items():
            for dataset, vals in datasets.items():
                if vals["C"] is not None:
                    rows.append({"Algorithm": algo, "Dataset": dataset, "C": vals["C"]})
        df = pd.DataFrame(rows)
        df_sub = df[df["Algorithm"].isin(algos_to_plot)]
        plt.figure(figsize=figsize)
        sns.barplot(data=df_sub, x="Dataset", y="C", hue="Algorithm")
        plt.title(f"{problem} – Combined Metric (C)")
        plt.ylabel("Combined Metric (C)")
        plt.xticks(rotation=30)
        plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
        plt.tight_layout()
        plt.show()


plot_algo_comparison (data_dict= data_dict, problems = [
                                        # 'Maximum Coverage', 
                                        # 'Maximum Cut', 
                                        'Influence Maximization Weighted',
                                        ],
                      algos_to_plot=["LLM2Prune", "QuickPrune"])

# %%
def _latex_escape(s: str) -> str:
    # Escape LaTeX special chars in simple labels
    return (s.replace('\\', r'\textbackslash{}')
             .replace('_', r'\_')
             .replace('%', r'\%')
             .replace('&', r'\&')
             .replace('#', r'\#')
             .replace('{', r'\{')
             .replace('}', r'\}')
             .replace('$', r'\$'))

def _fmt4(x):
    if x is None:
        return r'--'
    try:
        return f"{float(x):.4f}"
    except Exception:
        return r'--'

# %%
from matplotlib.table import table


def generate_latex_table_multi(data_dict, problems, algorithms, datasets=None, caption=None, label=None):
    """
    data_dict: nested dict (Problem -> Algorithm -> Dataset -> {P_r,P_g,C})
    problems: list[str]
    algorithms: list[str]
    datasets: optional list[str] (applied to each problem)
    caption/label: optional LaTeX caption/label.
    """

    # Column specification: left col + vertical bars separating algorithm blocks
    col_spec = "l|" + "|".join(["ccc"] * len(algorithms))

    # Top header
    top_header = [r"\textbf{Dataset}"]
    for idx, alg in enumerate(algorithms):
        alg_label = _latex_escape(alg).replace('*', r'\*')
        # add "|" only between algorithm blocks
        end_bar = "|" if idx < len(algorithms) - 1 else ""
        top_header.append(rf"\multicolumn{{3}}{{c{end_bar}}}{{\textbf{{{alg_label}}}}}")
    top_header = " & ".join(top_header) + r" \\"

    # Sub-header
    sub_header = [""]
    for _ in algorithms:
        sub_header += [r"\textbf{$P_r$}", r"\textbf{$P_g$}", r"\textbf{$C$}"]
    sub_header = " & ".join(sub_header) + r" \\"

    # light colors for ranks
    rank_colors = {1: "lightred", 2: "lightblue", 3: "lightgreen"}

    lines = []
    for prob in problems:
        if prob not in data_dict:
            continue
        # centered problem row
        lines.append(
            rf"\multicolumn{{{1+3*len(algorithms)}}}{{c}}{{\textbf{{{_latex_escape(prob)}}}}} \\"
        )

        lines.append(
            rf" \midrule"
        )
        algo_blocks = {a: data_dict[prob].get(a, {}) for a in algorithms}

        if datasets is None:
            seen = []
            for a in algorithms:
                for d in algo_blocks.get(a, {}).keys():
                    if d not in seen:
                        seen.append(d)
            prob_datasets = seen
        else:
            prob_datasets = datasets

        for ds in prob_datasets:
            # collect C values
            C_vals = []
            for alg in algorithms:
                m = algo_blocks.get(alg, {}).get(ds, {})
                try:
                    C_vals.append(float(m.get("C")))
                except:
                    C_vals.append(None)

            # rank values
            ranked = {}
            valid = [(i, c) for i, c in enumerate(C_vals) if c is not None]
            sorted_vals = sorted(valid, key=lambda x: x[1], reverse=True)
            for rank, (i, c) in enumerate(sorted_vals, start=1):
                if rank <= 3:
                    ranked[i] = rank

            row = [_latex_escape(ds)]
            for idx, alg in enumerate(algorithms):
                m = algo_blocks.get(alg, {}).get(ds, {})
                pr = _fmt4(m.get("P_r"))
                pg = _fmt4(m.get("P_g"))
                cval = _fmt4(m.get("C"))
                if idx in ranked:
                    color = rank_colors[ranked[idx]]
                    cval = rf"\textbf{{\textcolor{{{color}}}{{{cval}}}}}"
                row += [pr, pg, cval]
            lines.append(" & ".join(row) + r" \\")
        lines.append(r"\midrule")

    caption = caption or "Results across problems and datasets"
    label = label or "tab:multi_problem_algos"

    table = []
    table.append(r"\begin{table*}[h]")
    table.append(r"\centering")
    table.append(rf"\caption{{{caption}}}")
    table.append(r"\vspace{1em}")
    table.append(rf"\label{{{label}}}")
    table.append(r"\resizebox{\textwidth}{!}{%")  # start resize
    table.append(rf"\begin{{tabular}}{{{col_spec}}}")
    table.append(r"\toprule")
    table.append(top_header)
    table.append(sub_header)
    table.append(r"\midrule")
    table.extend(lines)
    table.append(r"\bottomrule")
    table.append(r"\end{tabular}")
    table.append(r"}")  # end resize
    table.append(r"\end{table*}")


    return "\n".join(table)


problems = [ "Maximum Coverage","Maximum Cut","Influence Maximization"]
algorithms = ["QuickPrune","SS","LLM2Prune","GCOMB-P","LeNSE","COMBHelper"]
datasets = ["Facebook", "DBLP", "Deezer", "Slashdot", "Wiki", "Twitter", "YouTube", "Skitter"]


caption = r"Comparison of pruning algorithms for size-constraint experiments. The best, second, and third results are highlighted in red, blue, and green, respectively. *Values are reported from \cite{ireland2022lense}, while **values are taken from \citep{pmlr-v258-nath25a}. “--” indicates that the corresponding algorithm obtained no reasonable result."

latex_str = generate_latex_table_multi(data_dict, problems, algorithms, datasets, caption= caption)
print(latex_str)
# Out:
# \begin{table*}[h]
# \centering
# \caption{Comparison of pruning algorithms for size-constraint experiments. The best, second, and third results are highlighted in red, blue, and green, respectively. *Values are reported from \cite{ireland2022lense}, while **values are taken from \citep{pmlr-v258-nath25a}. “--” indicates that the corresponding algorithm obtained no reasonable result.}
# \vspace{1em}
# \label{tab:multi_problem_algos}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{l|ccc|ccc|ccc|ccc|ccc|ccc}
# \toprule
# \textbf{Dataset} & \multicolumn{3}{c|}{\textbf{QuickPrune}} & \multicolumn{3}{c|}{\textbf{SS}} & \multicolumn{3}{c|}{\textbf{LLM2Prune}} & \multicolumn{3}{c|}{\textbf{GCOMB-P}} & \multicolumn{3}{c|}{\textbf{LeNSE}} & \multicolumn{3}{c}{\textbf{COMBHelper}} \\
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_box(data_dict, problems, algorithms=None):
    colors = {
        "SS": "#6A5ACD",
        "QuickPrune": "#FF6347",
        "LLM2Prune": "#FFB000",
        "LeNSE": "#20B2AA",
        "GCOMB-P": "#32CD32",
        "COMBHelper": "#FF69B4",
    }

    rows = []
    for problem in problems:
        algo_block = data_dict[problem]
        for algo, datasets in algo_block.items():
            if algorithms and algo not in algorithms:
                continue
            for ds, vals in datasets.items():
                if vals["C"] is not None:
                    rows.append({
                        "Problem": problem,
                        "Algorithm": algo,
                        "C": vals["C"]
                    })

    df = pd.DataFrame(rows)

    if algorithms:
        df["Algorithm"] = pd.Categorical(df["Algorithm"], categories=algorithms, ordered=True)

    plt.figure(figsize=(12, 4), dpi=300)
    sns.boxplot(
        data=df,
        x="Problem",
        y="C",
        hue="Algorithm",
        # notch=True,
        showcaps=False,
        palette=colors
    )
    # sns.violinplot(
    #     data=df,
    #     x="Problem",
    #     y="C",
    #     hue="Algorithm",
    #     palette=colors,
    #     # split=True,
    #     # cut =0,
    #     inner="quartile"
    # )

    # plt.ylim(0, 1.05)
    plt.xlabel("")
    plt.ylabel("Combined Matric,$C =P_rP_g$", fontsize=12)
    # plt.xticks(ha="right")
    plt.legend(title="Algorithm", bbox_to_anchor=(1.05, 1), loc="upper left", frameon=False)
    plt.tight_layout()
    sns.despine()
    plt.show()

# Example
plot_box(
    data_dict,
    ["Maximum Coverage", "Maximum Cut", "Influence Maximization"],
    algorithms=["QuickPrune", "SS", "LLM2Prune", "LeNSE", "GCOMB-P", "COMBHelper"]
)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

def plot_algo_comparison(data_dict, problems, algos_to_plot, figsize=(7, 5)):
    rows = []
    for problem in problems:
        for algo, datasets in data_dict[problem].items():
            for dataset, vals in datasets.items():
                if vals["C"] is not None:
                    rows.append({
                        "Problem": problem,
                        "Algorithm": algo,
                        "Dataset": dataset,
                        "C": vals["C"]
                    })

    df = pd.DataFrame(rows)
    df_sub = df[df["Algorithm"].isin(algos_to_plot)]

    # Short labels for problems
    problem_labels = {
        "Maximum Coverage Weighted": "MaxCov",
        "Maximum Cut Weighted": "MaxCut",
        "Influence Maximization Weighted": "IM"
    }
    df_sub["Problem"] = df_sub["Problem"].map(problem_labels)

    # Style
    sns.set_theme(style="whitegrid", font_scale=1.2)

    # Custom colors
    palette = {
        "LLM2Prune": "#FFB000",   # amber
        "QuickPrune": "#0072B2"   # blue
    }

    plt.figure(figsize=figsize)
    ax = sns.barplot(
        data=df_sub,
        x="Problem",
        y="C",
        hue="Algorithm",
        palette=palette,
        ci="sd",
        errcolor="black",
        errwidth=1.2,
        capsize=0.1
    )

    # Labels
    ax.set_ylabel("Combined Metric (C)", fontsize=13)
    ax.set_xlabel("")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=12)

    # Legend on top center
    ax.legend(
        title="Algorithm",
        loc="lower center",
        bbox_to_anchor=(0.5, 1.05),
        ncol=len(algos_to_plot),   # put all entries in one row
        frameon=False
    )

    sns.despine()
    plt.tight_layout()
    plt.show()


# Example call
plot_algo_comparison(
    data_dict=data_dict,
    problems=["Maximum Coverage Weighted", "Maximum Cut Weighted", "Influence Maximization Weighted"],
    algos_to_plot=["LLM2Prune", "QuickPrune"]
)
# Out:
# /tmp/ipykernel_4000354/1067493663.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub["Problem"] = df_sub["Problem"].map(problem_labels)
# /tmp/ipykernel_4000354/1067493663.py:39: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(
# /tmp/ipykernel_4000354/1067493663.py:39: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'black'}` instead.
#
#   ax = sns.barplot(
# /tmp/ipykernel_4000354/1067493663.py:39: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.2}` instead.
#
#   ax = sns.barplot(
# ...

# %%
data_dict['Influence Maximization Weighted']['LLM2Prune']
# Out:
# {'Facebook': {'P_r': 0.1923, 'P_g': 0.8751, 'C': 0.1683},
#  'DBLP': {'P_r': 0.4678, 'P_g': 0.9841, 'C': 0.4604},
#  'Deezer': {'P_r': 0.1403, 'P_g': 0.9907, 'C': 0.139},
#  'Slashdot': {'P_r': 0.207, 'P_g': 0.9926, 'C': 0.2055},
#  'Wiki': {'P_r': 0.1651, 'P_g': 0.9214, 'C': 0.1521},
#  'Twitter': {'P_r': 0.8929, 'P_g': 0.9876, 'C': 0.8818},
#  'YouTube': {'P_r': 0.9016, 'P_g': 0.9954, 'C': 0.8975}}

# %%
# problems = [ "Maximum Coverage","Maximum Cut","Influence Maximization"]
# algorithms = ["QuickPrune","SS","LLM2Prune","GCOMB-P","LeNSE","COMBHelper"]
# datasets = ["Facebook", "DBLP", "Deezer", "Slashdot", "Wiki", "Twitter", "YouTube", "Skitter"]


# caption = r"Comparison of pruning algorithms for size-constraint experiments. The best, second, and third results are highlighted in red, blue, and green, respectively. *Values are reported from \cite{ireland2022lense}, while **values are taken from \citep{pmlr-v258-nath25a}. “--” indicates that the corresponding algorithm obtained no reasonable result."

# latex_str = generate_latex_table_multi(data_dict, problems, algorithms, datasets, caption= caption)
# print(latex_str)

# %% [markdown]
# # Time

# %%
runtime_data = {
    "Maximum Coverage": {
        "QuickPrune": {
            "Facebook": 0.064, "Wiki": 0.094, "Deezer": 0.437, "Slashdot": 0.590,
            "Twitter": 1.075, "DBLP": 1.208, "YouTube": 5.443, "Skitter": 10.317
        },
        "SS": {
            "Facebook": 3.178, "Wiki": 5.804, "Deezer": 41.995, "Slashdot": 58.281,
            "Twitter": 120.555, "DBLP": 168.011, "YouTube": 769.871, "Skitter": 2238.035
        },
        "GCOMB-P": {
            "Facebook": 0.002, "Wiki": 0.004, "Deezer": 0.026, "Slashdot": 0.039,
            "Twitter": 0.058, "DBLP": 0.197, "YouTube": 0.501, "Skitter": 0.982
        },
        "LeNSE": {
            "Facebook": 27.024, "Wiki": 25.238, "Deezer": 34.210, "Slashdot": 38.315,
            "Twitter": 76.827, "DBLP": 38.325, "YouTube": 231.557, "Skitter": 1593.406
        }
    },
    "Maximum Cut": {
        "QuickPrune": {
            "Facebook": 0.041, "Wiki": 0.063, "Deezer": 0.225, "Slashdot": 0.324,
            "Twitter": 0.419, "DBLP": 0.945, "YouTube": 3.260, "Skitter": 5.971
        },
        "SS": {
            "Facebook": 2.814, "Wiki": 4.652, "Deezer": 33.338, "Slashdot": 49.481,
            "Twitter": 98.327, "DBLP": 136.161, "YouTube": 711.806, "Skitter": 1788.188
        },
        "GCOMB-P": {
            "Facebook": 0.002, "Wiki": 0.004, "Deezer": 0.029, "Slashdot": 0.045,
            "Twitter": 0.055, "DBLP": 0.190, "YouTube": 0.622, "Skitter": 0.958
        },
        "LeNSE": {
            "Facebook": 28.931, "Wiki": 30.614, "Deezer": 36.512, "Slashdot": 40.893,
            "Twitter": 78.452, "DBLP": 39.743, "YouTube": 233.816, "Skitter": 1600.123
        }
    },
    "Influence Maximization": {
        "QuickPrune": {
            "Facebook": 0.093, "Wiki": 2.098, "Deezer": 0.055, "Slashdot": 11.300,
            "Twitter": 160.952, "DBLP": 11.138, "YouTube": 32.916, "Skitter": 255.450
        },
        "SS": {
            "Facebook": 24.960, "Wiki": 86.424, "Deezer": 11.371, "Slashdot": 102.259,
            "Twitter": 1242.836, "DBLP": 118.537, "YouTube": 3652.793, "Skitter": 10433.744
        },
        "GCOMB-P": {
            "Facebook": 0.002, "Wiki": 0.004, "Deezer": 0.023, "Slashdot": 0.035,
            "Twitter": 0.051, "DBLP": 0.205, "YouTube": 0.515, "Skitter": 0.980
        },
        "LeNSE": {
            "Facebook": 31.453, "Wiki": 36.476, "Deezer": 42.164, "Slashdot": 44.193,
            "Twitter": 81.610, "DBLP": 49.286, "YouTube": 238.906, "Skitter": 1607.605
        }
    }
}

# %%
for problem in [
    'Maximum Coverage',
    'Maximum Cut',
    'Influence Maximization',
]:
    datasets = ['Facebook', 'DBLP', 'Deezer', 'Slashdot', 'Wiki', 'Twitter', 'YouTube', 'Skitter']

    for algo in ['LLM2Prune', 'COMBHelper']:

        # ensure algorithm dict exists
        if algo not in runtime_data[problem]:
            runtime_data[problem][algo] = {}

        for dataset in datasets:
            try:
                results = load_from_pickle(f'/home/grads/a/anath/Results/{problem}/{dataset}/{algo}')
                runtime_data[problem][algo][dataset] = float(results['TimeToPrune'].iloc[0])
            except Exception:
                runtime_data[problem][algo][dataset] = None  # keep placeholder if missing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Flatten dict -> dataframe
rows = []
for problem, algos in runtime_data.items():
    for algo, datasets in algos.items():
        for dataset, val in datasets.items():
            if val is not None:
                rows.append({
                    "Problem": problem,
                    "Algorithm": algo,
                    "Dataset": dataset,
                    "Runtime": float(val)
                })
df = pd.DataFrame(rows)

# Global style
sns.set_theme(style="whitegrid", font_scale=1.3)
plt.rcParams["axes.linewidth"] = 1.2
plt.rcParams["axes.edgecolor"] = "0.2"

# 🔹 Manually assign colors (LLM2Prune = standout warm orange)
color_map = {
    "LLM2Prune": "#f6981c",   # bright orange (highlight, only warm color)
    "QuickPrune": "#ee7725",  # soft blue
    "SS": "#594ee8",          # purple
    "GCOMB-P": "#42c0fa",     # cyan
    "COMBHelper": "#36a654",  # gray-blue
    "LeNSE": "#0c6fff",       # green
    # add more algorithms here if needed
}

algorithms = df["Algorithm"].unique()

for problem in df["Problem"].unique():
    plt.figure(figsize=(14, 6))
    sub = df[df["Problem"] == problem]

    ax = sns.barplot(
        data=sub,
        x="Dataset", y="Runtime", hue="Algorithm",
        palette=color_map, dodge=True,
        edgecolor=None, linewidth=0   # ⬅️ removed dark edges
    )

    # Axes styling
    ax.set_yscale("log")
    ax.set_ylabel("Runtime (seconds, log scale)", weight="bold")
    ax.set_xlabel("")
    ax.tick_params(axis="x", rotation=30)
    sns.despine()

    # Custom legend (horizontal, clean, above plot)
    handles, labels = [], []
    for algo in algorithms:
        handles.append(Patch(facecolor=color_map[algo], edgecolor="none", label=algo))
    ax.legend(
        handles, algorithms,
        loc="lower center",
        bbox_to_anchor=(0.5, 1.05),
        ncol=len(algorithms),
        frameon=False,
        fontsize=12
    )

    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections import register_projection
from matplotlib.projections.polar import PolarAxes
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D


# ---------- Radar Factory ----------
def radar_factory(num_vars, frame='circle'):
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarTransform(PolarAxes.PolarTransform):
        def transform_path_non_affine(self, path):
            if path._interpolation_steps > 1:
                path = path.interpolated(num_vars)
            return Path(self.transform(path.vertices), path.codes)

    class RadarAxes(PolarAxes):
        name = 'radar'
        PolarTransform = RadarTransform

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError(f"Unknown value for frame: {frame}")

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                spine = Spine(self, 'circle',
                              Path.unit_regular_polygon(num_vars))
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError(f"Unknown value for frame: {frame}")

    register_projection(RadarAxes)
    return theta


# ---------- Data Prep ----------
rows = []
for problem, algos in runtime_data.items():
    for algo, datasets in algos.items():
        for dataset, val in datasets.items():
            if val is not None:
                rows.append({
                    "Problem": problem,
                    "Algorithm": algo,
                    "Dataset": dataset,
                    "Runtime": float(val)
                })
df = pd.DataFrame(rows)

algos_keep = ["SS", "QuickPrune", "LLM2Prune", "LeNSE"]
df = df[df["Algorithm"].isin(algos_keep)]
df["Score"] = np.log10(df["Runtime"])   # absolute log runtime


# ---------- Plot ----------
colors = {
    "SS": "#6A5ACD",
    "QuickPrune": "#FF6347",
    "LLM2Prune": "#FFB000",
    "LeNSE": "#20B2AA",
}

# for problem in df["Problem"].unique():
#     sub = df[df["Problem"] == problem]
#     categories = sub["Dataset"].unique()
#     N = len(categories)
#     theta = radar_factory(N, frame="polygon")

#     fig, ax = plt.subplots(figsize=(8, 8),
#                            subplot_kw=dict(projection="radar"))
#     fig.subplots_adjust(top=0.85, bottom=0.05)

#     # plot each algorithm
#     for algo, color in colors.items():
#         values = (
#             sub[sub["Algorithm"] == algo]
#             .set_index("Dataset")
#             .reindex(categories)["Score"]
#             .fillna(0)
#             .tolist()
#         )
#         ax.plot(theta, values, color=color, linewidth=2, label=algo)
#         ax.fill(theta, values, facecolor=color, alpha=0.25)

#     ax.set_varlabels(categories)
#     ax.set_ylim(-1.5, 3.5)
#     # ax.set_title(f"{problem} – log₁₀ Runtime", size=14, pad=20)
#     ax.legend(loc="upper right", bbox_to_anchor=(1.2, 1.1), frameon=False)

#     plt.show()

# %%
# # ---------- Plot ----------
# colors = {
#     "SS": "#6A5ACD",
#     "QuickPrune": "#FF6347",
#     "LLM2Prune": "#FFB000",
#     "LeNSE": "#20B2AA",
# }

# problems = df["Problem"].unique()
# ncols = len(problems)

# fig, axs = plt.subplots(figsize=(5*ncols + 3, 6),  # widened figure
#                         nrows=1, ncols=ncols,
#                         subplot_kw=dict(projection="radar"))

# if ncols == 1:  # ensure axs is iterable
#     axs = [axs]

# for ax, problem in zip(axs, problems):
#     sub = df[df["Problem"] == problem]
#     categories = sub["Dataset"].unique()
#     N = len(categories)
#     theta = radar_factory(N, frame="polygon")

#     # Plot each algorithm
#     for algo, color in colors.items():
#         values = (
#             sub[sub["Algorithm"] == algo]
#             .set_index("Dataset")
#             .reindex(categories)["Score"]
#             .fillna(0)
#             .tolist()
#         )
#         ax.plot(theta, values, color=color, linewidth=2, label=algo)
#         ax.fill(theta, values, facecolor=color, alpha=0.25)

#     # Remove dataset labels + radial ticks
#     ax.set_ylim(-1.5, 5)
#     ax.set_varlabels([])  
#     ax.set_yticklabels([])  
#     ax.set_title(f"{problem}", size=14, pad=20)

# # ---------- Shared Legend ----------
# handles, labels = axs[0].get_legend_handles_labels()
# fig.legend(handles, labels,
#            loc="lower center",
#            ncol=len(algos_keep),
#            frameon=False,
#            fontsize=12)

# # 🔹 Add more horizontal spacing
# plt.subplots_adjust(wspace=0.4, bottom=0.15)  # increase wspace for separation
# plt.tight_layout(rect=[0, 0.12, 1, 1])        # leave space for legend
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# from matplotlib.patches import Circle, RegularPolygon
# from matplotlib.path import Path
# from matplotlib.projections import register_projection
# from matplotlib.projections.polar import PolarAxes
# from matplotlib.spines import Spine
# from matplotlib.transforms import Affine2D


# # ---------- Radar Factory ----------
# def radar_factory(num_vars, frame='circle', midpoint=True):
#     """
#     num_vars : number of sides (datasets)
#     frame    : 'circle' or 'polygon'
#     midpoint : if True, angles are shifted so points fall in the middle of polygon sides
#     """
#     base_theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

#     if midpoint:
#         step = (2*np.pi) / num_vars
#         theta = base_theta + step / 2
#     else:
#         theta = base_theta

#     class RadarTransform(PolarAxes.PolarTransform):
#         def transform_path_non_affine(self, path):
#             if path._interpolation_steps > 1:
#                 path = path.interpolated(num_vars)
#             return Path(self.transform(path.vertices), path.codes)

#     class RadarAxes(PolarAxes):
#         name = 'radar'
#         PolarTransform = RadarTransform

#         def __init__(self, *args, **kwargs):
#             super().__init__(*args, **kwargs)
#             self.set_theta_zero_location('N')

#         def fill(self, *args, closed=True, **kwargs):
#             return super().fill(closed=closed, *args, **kwargs)

#         def plot(self, *args, **kwargs):
#             lines = super().plot(*args, **kwargs)
#             for line in lines:
#                 self._close_line(line)

#         def _close_line(self, line):
#             x, y = line.get_data()
#             if x[0] != x[-1]:
#                 x = np.append(x, x[0])
#                 y = np.append(y, y[0])
#                 line.set_data(x, y)

#         def set_varlabels(self, labels):
#             # ✅ explicitly use shifted theta for label placement
#             self.set_thetagrids(np.degrees(theta), labels)

#         def _gen_axes_patch(self):
#             if frame == 'circle':
#                 return Circle((0.5, 0.5), 0.5)
#             elif frame == 'polygon':
#                 return RegularPolygon((0.5, 0.5), num_vars,
#                                       radius=.5, edgecolor="k")
#             else:
#                 raise ValueError(f"Unknown value for frame: {frame}")

#         def _gen_axes_spines(self):
#             if frame == 'circle':
#                 return super()._gen_axes_spines()
#             elif frame == 'polygon':
#                 spine = Spine(self, 'circle',
#                               Path.unit_regular_polygon(num_vars))
#                 spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
#                                     + self.transAxes)
#                 return {'polar': spine}
#             else:
#                 raise ValueError(f"Unknown value for frame: {frame}")

#     register_projection(RadarAxes)
#     return theta


# # ---------- Data Prep ----------
# rows = []
# for problem, algos in runtime_data.items():
#     for algo, datasets in algos.items():
#         for dataset, val in datasets.items():
#             if val is not None:
#                 rows.append({
#                     "Problem": problem,
#                     "Algorithm": algo,
#                     "Dataset": dataset,
#                     "Runtime": float(val)
#                 })
# df = pd.DataFrame(rows)

# algos_keep = ["SS", "QuickPrune", "LLM2Prune", "LeNSE"]
# df = df[df["Algorithm"].isin(algos_keep)]
# df["Score"] = np.log10(df["Runtime"])   # absolute log runtime


# # ---------- Plot ----------
# colors = {
#     "SS": "#6A5ACD",
#     "QuickPrune": "#FF6347",
#     "LLM2Prune": "#FFB000",
#     "LeNSE": "#20B2AA",
# }

# problems = df["Problem"].unique()
# ncols = len(problems)

# fig, axs = plt.subplots(figsize=(5*ncols+3, 6),
#                         nrows=1, ncols=ncols,
#                         subplot_kw=dict(projection="radar"))

# if ncols == 1:
#     axs = [axs]

# for ax, problem in zip(axs, problems):
#     sub = df[df["Problem"] == problem]
#     categories = sub["Dataset"].unique()
#     N = len(categories)
#     theta = radar_factory(N, frame="polygon", midpoint=True)  # midpoint = side-centered

#     # Plot each algorithm
#     for algo, color in colors.items():
#         values = (
#             sub[sub["Algorithm"] == algo]
#             .set_index("Dataset")
#             .reindex(categories)["Score"]
#             .fillna(0)
#             .tolist()
#         )
#         ax.plot(theta, values, color=color, linewidth=2, label=algo)
#         ax.fill(theta, values, facecolor=color, alpha=0.25)

#     # ✅ Show dataset names on sides
#     ax.set_ylim(-1.5, 4.6)
#     ax.set_varlabels(categories)
#     ax.set_yticklabels([])  
#     ax.set_title(f"{problem}", size=14, pad=20)

# # ---------- Shared Legend ----------
# handles, labels = axs[0].get_legend_handles_labels()
# fig.legend(handles, labels,
#            loc="lower center",
#            ncol=len(algos_keep),
#            frameon=False,
#            fontsize=12)

# plt.subplots_adjust(wspace=0.5, bottom=0.15)  
# plt.tight_layout(rect=[0, 0.12, 1, 1])  
# plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections import register_projection
from matplotlib.projections.polar import PolarAxes
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D

# ---------- Global Style ----------
plt.rcParams["figure.dpi"] = 400       # high DPI
plt.rcParams["savefig.dpi"] = 300      # high-quality saves
plt.rcParams["font.size"] = 14         # base font size
plt.rcParams["axes.titlesize"] = 16    # title font
plt.rcParams["axes.labelsize"] = 14    # axis label font
plt.rcParams["legend.fontsize"] = 13   # legend font
plt.rcParams["xtick.labelsize"] = 15   # tick font
plt.rcParams["ytick.labelsize"] = 13

plt.rcParams["pdf.fonttype"] = 42    # ensures TrueType, not Type 3
plt.rcParams["ps.fonttype"] = 42
# plt.rcParams["font.family"] = "Helvetica"   # or "Arial"

# ---------- Radar Factory ----------
def radar_factory(num_vars, frame='circle', midpoint=True):
    base_theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)
    if midpoint:
        step = (2*np.pi) / num_vars
        theta = base_theta + step / 2
    else:
        theta = base_theta

    class RadarTransform(PolarAxes.PolarTransform):
        def transform_path_non_affine(self, path):
            if path._interpolation_steps > 1:
                path = path.interpolated(num_vars)
            return Path(self.transform(path.vertices), path.codes)

    class RadarAxes(PolarAxes):
        name = 'radar'
        PolarTransform = RadarTransform

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels, fontsize=13)  # larger labels

        def _gen_axes_patch(self):
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError(f"Unknown value for frame: {frame}")

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                spine = Spine(self, 'circle',
                              Path.unit_regular_polygon(num_vars))
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError(f"Unknown value for frame: {frame}")

    register_projection(RadarAxes)
    return theta


# ---------- Data Prep ----------
rows = []
for problem, algos in runtime_data.items():
    for algo, datasets in algos.items():
        for dataset, val in datasets.items():
            if val is not None:
                rows.append({
                    "Problem": problem,
                    "Algorithm": algo,
                    "Dataset": dataset,
                    "Runtime": float(val)
                })
df = pd.DataFrame(rows)

algos_keep = ["SS", "QuickPrune", "LLM2Prune", "LeNSE"]
df = df[df["Algorithm"].isin(algos_keep)]
df["Score"] = np.log10(df["Runtime"])   # absolute log runtime


# ---------- Plot ----------
colors = {
    "SS": "#6A5ACD",
    "QuickPrune": "#FF6347",
    "LLM2Prune": "#FFB000",
    "LeNSE": "#20B2AA",
}

problems = df["Problem"].unique()
ncols = len(problems)

fig, axs = plt.subplots(figsize=(5*ncols+3, 6),
                        nrows=1, ncols=ncols,
                        subplot_kw=dict(projection="radar"))

if ncols == 1:
    axs = [axs]

for ax, problem in zip(axs, problems):
    sub = df[df["Problem"] == problem]
    categories = sub["Dataset"].unique()
    N = len(categories)
    theta = radar_factory(N, frame="polygon", midpoint=True)

    # Plot each algorithm
    for algo, color in colors.items():
        values = (
            sub[sub["Algorithm"] == algo]
            .set_index("Dataset")
            .reindex(categories)["Score"]
            .fillna(0)
            .tolist()
        )
        ax.plot(theta, values, color=color, linewidth=2, label=algo)
        ax.fill(theta, values, facecolor=color, alpha=0.25)

    # labels + limits
    ax.set_ylim(-1.5, 4.6)
    ax.set_varlabels(categories)
    ax.set_yticklabels([])
    ax.set_title(f"{problem}", size=18, pad=25, weight="bold")

# ---------- Shared Legend ----------
handles, labels = axs[0].get_legend_handles_labels()
# fig.legend(handles, labels,
#            loc="lower center",
#            ncol=len(algos_keep),
#            frameon=False,
#            fontsize=14)

# fig.legend(handles, labels, loc="lower center", ncol=len(algos_keep),
#            frameon=True, fancybox=True, shadow=False,
#            framealpha=0.9, facecolor="white", edgecolor="0.8")

from matplotlib.patches import Patch

# ---------- Shared Legend ----------
handles = [Patch(facecolor=colors[algo], edgecolor="none", label=algo) 
           for algo in algos_keep]

fig.legend(handles,
           [h.get_label() for h in handles],
           loc="lower center",
           ncol=len(algos_keep),
           frameon=False,
           fontsize=20)


plt.subplots_adjust(wspace=0.5, bottom=0.15)  
plt.tight_layout(rect=[0, 0.12, 1, 1])
plt.savefig("radar_runtime_comparison.pdf", bbox_inches="tight",dpi=500)
plt.show()
