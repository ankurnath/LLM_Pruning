# %%
from utils import load_from_pickle

# %% [markdown]
# # Maximum Cut with negative weights

# %%
data = load_from_pickle('qs_maxcut_negative_greedy.pkl')

# %%
data[['Dataset','Size Reduction(%)','Ratio(%)']]
# Out:
#     Dataset  Size Reduction(%)  Ratio(%)
# 0  Facebook              82.66     97.04
# 1      Wiki              89.87     97.73
# 2    Deezer              97.30    100.00
# 3  Slashdot              98.41     99.07
# 4   Twitter              98.33     99.70
# 5      DBLP              99.48     99.44
# 6   YouTube              99.89     99.92
# 7   Skitter              99.93    100.00
